# %% [markdown]
# ![](https://github.com/Shayros/world_development_explorer/raw/main/images/women-in-tech-pillar-page-in-person-communities-for-women.png)
# *Image from: builtin.com*
#
# # The increase of women in the workplace drives an increase in GDP
#
# **Author**: Shaimar R. González Morales
#
# **Date**: 4/04/2021

# %% [markdown]
# United Stated have seing an increase in women in the workplace since 1930 and 1970 and this increase continues (1). Nevertheless, payment inequality in different work sectors remains a big issue but stigma around working married women in the US has reduced (1). The recent movie "Picture a Scientist" highlight that although the stigma have being reduce, the discrimination against women in the workplace has not (2). In the movie it showcase a study that was performed where a female can submit a CV or resume with the same credentials than the male and the male always recieved a better feedback than the female applicant (2).
#
# ![](https://github.com/Shayros/world_development_explorer/raw/main/images/shutterstock_751868104-1-1024x1024.jpg)
# *Image from: nederlia.com*
#
# The descrimination against female names in applications does not even account for the discrimination either sexual or gender base that many women face once that they are hired. Unfortanetlly many countries doesn't have laws that proctec women in the workplace. Also, many countries doesn't have equality when referring to education, which can also contribute to less women in the workplace.
#
# ![](https://github.com/Shayros/world_development_explorer/raw/main/images/pos.cause.png)
# *Image from: https://www.cfr.org/womens-participation-in-global-economy/*
#
# In many countries of these counrties there still a high level of stigma of women being in the workplace. The World Bank showed that 15 countries with less women in the workplace belong Middle East and North Africa (MENA) in 2015 (3). Despite that in many cases females were outperforming their male counterparts (3). The patriarcal society in these countries and the lack of rules that protect women in the workplaces not only towards harrasment but that guarantee equal payment is pushing women out of the workforce if they even get the job in the first place. According to El-Swais article, Morocco from this list of counties is the only one that by 2015 had laws again gender discrimination during hiring and equal payment and Algeria joined later with laws that also protect equal payment (3).
#
# ![](https://github.com/Shayros/world_development_explorer/raw/main/images/Menacont.png)
# *Image from: https://blogs.worldbank.org/arabvoices/despite-high-education-levels-arab-women-still-don-t-have-jobs*
#
# El-Sawais said that these gap between male and female in the workplace produce a 27% loss in income in these countries, which makes you question then why they still are following this practices.
#
# I utilized some of the data from World Bank to explore the percentage of women in the workforce in countries of highest GDP and compare with some countries with low women in the workforce to determine if is seems to be a trend. This is very important not only to help increase the women in the workforce in other countries but also in increase equity in the workplace especially in the STEM fields. Due to the recent pandemic women have suffer more due to deal with child care, and child education will still working, as most of daycare were close or not safe during these times. We know that the economy have suffer during the pandemic, but how much will this be because women were force to stay taking care of the children affecting their work productivity and in some cases quitting their work because of this?
#
# Although this database doesn't include data during the pandemic, we can determine whether the increase in the percentage of women in the workforce in other countries even if is slighthy, contribute to a higher GDP. This is important because we can go back to the literature and determine what happened during that year that stimulate the economy and what policies the counrty did to increase the number of women working.

# %% [markdown]
# The data was obtained from http://www.worlddev.xyz/, which allow to visualize current data from the World Bank in a way that is more accessible.
#
# First, to performed this analysis I chose Economy and Growth (GDP per capita (cureent international $)) and Education (labor force total) as my indicators. The countries that were selected were Algeria, Canada, China, Egypt, Germany, India, Iran, Italy, Japan, New Zealand, Saudi Arabia, United Kingdom, United States and Yemen from 2010 to 2019. This was done as most of this countries are the ones with highest GDP and others like Yemen are ones with low  women in the workplace.

# %% [markdown]
# A bar graph was used just to ilustrate the amout of GDP among these countries.

# %% [markdown]
# ## 1.Importing the data

# %%
import pandas as pd 
import plotly.express as px #visualization

# %%
df =pd.read_csv("https://github.com/Shayros/world_development_explorer/raw/main/Project/wdi_data14countries.csv") # adding the data to be analyzed 
df.shape #This data include only the countries discussed above
# Out:
# (134, 10)

# %% [markdown]
# ## 2. Acessing and filtering the data

# %%
df.head() #give us an idea of what type of data is included and the name of our columns
# Out:
#    Unnamed: 0  Year  ...         Income Group  Lending Type
# 0           0  2010  ...  Lower middle income          IBRD
# 1           1  2011  ...  Lower middle income          IBRD
# 2           2  2012  ...  Lower middle income          IBRD
# 3           3  2013  ...  Lower middle income          IBRD
# 4           4  2014  ...  Lower middle income          IBRD
#
# [5 rows x 10 columns]

# %%
df.drop(columns=["Unnamed: 0"], inplace=True) # You can observed above that there is a column title unnamed
df.sample() #let's drop that column and observed the data without that column
# Out:
#     Year  SL.TLF.TOTL.IN  ...  Income Group    Lending Type
# 86  2016        66854063  ...   High income  Not classified
#
# [1 rows x 9 columns]

# %% [markdown]
# ## 3. Indicators

# %%
df.info() # allow us to observed the columns name and the type of data in that column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               134 non-null    int64
#  1   SL.TLF.TOTL.IN     134 non-null    int64
#  2   NY.GDP.PCAP.PP.CD  134 non-null    float64
#  3   SL.TLF.TOTL.FE.ZS  134 non-null    float64
#  4   Country Code       134 non-null    object
#  5   Country Name       134 non-null    object
#  6   Region             134 non-null    object
#  7   Income Group       134 non-null    object
#  8   Lending Type       134 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 9.5+ KB

# %% [markdown]
# ### Indicators
#
# * Year-> In this case the years are from 2010-2019
#
#
# * SL.TFL.TOTL.IN-> Labor force total
#
#
# * NY.GDP.PCAP.PP.CD-> GDP per capita, PPP (current international $)
#
#
# * SL.TLF.TOTL.FE.ZS-> Labor force, female (% of total labor force)
#
#
# * Country Code-> Three letter code that indentifies the counrty exp. USA
#
#
# * Country Name-> Full name of the Country exp. Algeria
#
#
# * Region-> Divide countries by East Asia & Pacific, North America, Middle East & North Africa, Europe & Central Asia, South Asia, Sub-Saharan Africa and Latin America & Caribbean
#
#
# * Income Group-> Does the country have low, low middle, upper middle, or high income
#
#
# * Lending Type-> International Bank for Reconstruction and Developmen (IBRD), International Development Association (IDA) or blended clasifications. And countries that don't have information will appear as Not classified.

# %% [markdown]
# ## 4. Bar graph to assess GDP in selected countries

# %%
import plotly.io as pio
pio.templates.default="plotly_dark" #make the plot black
fig = px.bar(data_frame=df, 
             x="Country Code", y="NY.GDP.PCAP.PP.CD",  # I utilized the country code because the name were too long
             color="Country Name", #legend
             title="GDP per capita in selected countries (2010-2019)", 
             animation_frame="Year",
             labels={
                     "NY.GDP.PCAP.PP.CD": "GDP per capita, PPP (current international $)" # change title to be same as it in the site
             },
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3b95c65b-da54-409c-988a-7454cdf32157" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b95c65b-da54-409c-988a-7454cdf32157")) {
#                     Plotly.newPlot(
#                         '3b95c65b-da54-409c-988a-7454cdf32157',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Algeria<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Algeria", "marker": {"color": "#636efa"}, "name": "Country Name=Algeria", "offsetgroup": "Country Name=Algeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["DZA"], "xaxis": "x", "y": [13095.4468249877], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Canada<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Canada", "marker": {"color": "#EF553B"}, "name": "Country Name=Canada", "offsetgroup": "Country Name=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["CAN"], "xaxis": "x", "y": [40019.926250234705], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=China<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=China", "marker": {"color": "#00cc96"}, "name": "Country Name=China", "offsetgroup": "Country Name=China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["CHN"], "xaxis": "x", "y": [9253.7651876772], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Egypt, Arab Rep.<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Egypt, Arab Rep.", "marker": {"color": "#ab63fa"}, "name": "Country Name=Egypt, Arab Rep.", "offsetgroup": "Country Name=Egypt, Arab Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["EGY"], "xaxis": "x", "y": [9522.5101985566], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Germany<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Germany", "marker": {"color": "#FFA15A"}, "name": "Country Name=Germany", "offsetgroup": "Country Name=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["DEU"], "xaxis": "x", "y": [38982.426304563596], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=India<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#19d3f3"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["IND"], "xaxis": "x", "y": [4236.744236473301], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Iran, Islamic Rep.<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Iran, Islamic Rep.", "marker": {"color": "#FF6692"}, "name": "Country Name=Iran, Islamic Rep.", "offsetgroup": "Country Name=Iran, Islamic Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["IRN"], "xaxis": "x", "y": [17388.8956143824], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Italy<br>Year=2010<br>Country Code=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Italy", "marker": {"color": "#B6E880"}, "name": "Country Name=Italy", "offsetgroup": "Country Name=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["ITA"], "xaxis": "x", "y": [35185.29289013], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Japan<b ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [

# %%
fig.write_html("bargraphGDP.html")

# %% [markdown]
# Here in this graph we can observed that United States, Germany and Canada has the higher GDP and among the lowest are Yemen and India.I run a similar raph with women in the workforce as my variable.

# %% [markdown]
# ## 5. Bar graph to assess female labor force in selected countries

# %%
import plotly.io as pio
pio.templates.default="plotly_dark" #make the plot black
fig = px.bar(data_frame=df, 
             x="Country Code", y="SL.TLF.TOTL.FE.ZS",  # I utilized labor force %
             color="Country Name", #legend
             title="GDP per capita in selected countries (2010-2019)", 
             animation_frame="Year",
             labels={
                     "SL.TLF.TOTL.FE.ZS": "Labor force, female (% of total labor force)" # change title to be same as it in the site
             },
             )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ed8fc632-6e0b-4538-888b-58f12d9ee6f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ed8fc632-6e0b-4538-888b-58f12d9ee6f6")) {
#                     Plotly.newPlot(
#                         'ed8fc632-6e0b-4538-888b-58f12d9ee6f6',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Algeria<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=Algeria", "marker": {"color": "#636efa"}, "name": "Country Name=Algeria", "offsetgroup": "Country Name=Algeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["DZA"], "xaxis": "x", "y": [16.8828113903], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Canada<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=Canada", "marker": {"color": "#EF553B"}, "name": "Country Name=Canada", "offsetgroup": "Country Name=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["CAN"], "xaxis": "x", "y": [47.1342097771], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=China<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=China", "marker": {"color": "#00cc96"}, "name": "Country Name=China", "offsetgroup": "Country Name=China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["CHN"], "xaxis": "x", "y": [44.0790545732], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Egypt, Arab Rep.<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=Egypt, Arab Rep.", "marker": {"color": "#ab63fa"}, "name": "Country Name=Egypt, Arab Rep.", "offsetgroup": "Country Name=Egypt, Arab Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["EGY"], "xaxis": "x", "y": [22.9805449458], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Germany<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=Germany", "marker": {"color": "#FFA15A"}, "name": "Country Name=Germany", "offsetgroup": "Country Name=Germany", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["DEU"], "xaxis": "x", "y": [45.5799785896], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=India<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#19d3f3"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["IND"], "xaxis": "x", "y": [23.032538101999997], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Iran, Islamic Rep.<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=Iran, Islamic Rep.", "marker": {"color": "#FF6692"}, "name": "Country Name=Iran, Islamic Rep.", "offsetgroup": "Country Name=Iran, Islamic Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["IRN"], "xaxis": "x", "y": [18.2125923279], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Italy<br>Year=2010<br>Country Code=%{x}<br>Labor force, female (% of total labor force)=%{y}", "legendgroup": "Country Name=Italy", "marker": {"color": "#B6E880"}, "name": "Country Name=Italy", "offsetgroup": "Country Name=Italy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["ITA"], "xaxis": "x", "y": [41.1658574987], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Japan<br>Year=2010<br>Country Code= ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "Year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2010"], {"frame": {"duration": 0, "redraw": true}, "fr

# %%
fig.write_html("bargraphlabor.html")

# %% [markdown]
# As you can see in this graph Iran, Yemen,Algeria and Saudi Arabia are amoung the counrties in this list with less female workforce. I used a buble graph to ilustrate the relation between GDP and women workforce.

# %% [markdown]
# ## 6. Bubble graph to assess the relation between GDP and female in the workforce for the selected countries

# %%
px.scatter(df, x="NY.GDP.PCAP.PP.CD", y="SL.TLF.TOTL.FE.ZS", animation_frame="Year", animation_group="Country Name",
           size="SL.TLF.TOTL.FE.ZS", color="Country Name", hover_name="Country Name",labels={
                     "SL.TLF.TOTL.FE.ZS": "Labor force, female (% of total labor force)",
                      "NY.GDP.PCAP.PP.CD": "GDP per capita, PPP (current international $)", # change title to be same as it in the site
             }, )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="268ac339-2354-4d33-ba13-1584f2a7f050" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("268ac339-2354-4d33-ba13-1584f2a7f050")) {
#                     Plotly.newPlot(
#                         '268ac339-2354-4d33-ba13-1584f2a7f050',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Algeria<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Algeria"], "ids": ["Algeria"], "legendgroup": "Country Name=Algeria", "marker": {"color": "#636efa", "size": [16.8828113903], "sizemode": "area", "sizeref": 0.11972850883275, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Algeria", "showlegend": true, "type": "scatter", "x": [13095.4468249877], "xaxis": "x", "y": [16.8828113903], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Canada<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Canada"], "ids": ["Canada"], "legendgroup": "Country Name=Canada", "marker": {"color": "#EF553B", "size": [47.1342097771], "sizemode": "area", "sizeref": 0.11972850883275, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Canada", "showlegend": true, "type": "scatter", "x": [40019.926250234705], "xaxis": "x", "y": [47.1342097771], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=China<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["China"], "ids": ["China"], "legendgroup": "Country Name=China", "marker": {"color": "#00cc96", "size": [44.0790545732], "sizemode": "area", "sizeref": 0.11972850883275, "symbol": "circle"}, "mode": "markers", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [9253.7651876772], "xaxis": "x", "y": [44.0790545732], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Egypt, Arab Rep.<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Egypt, Arab Rep."], "ids": ["Egypt, Arab Rep."], "legendgroup": "Country Name=Egypt, Arab Rep.", "marker": {"color": "#ab63fa", "size": [22.9805449458], "sizemode": "area", "sizeref": 0.11972850883275, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Egypt, Arab Rep.", "showlegend": true, "type": "scatter", "x": [9522.5101985566], "xaxis": "x", "y": [22.9805449458], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Germany<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Germany"], "ids": ["Germany"], "legendgroup": "Country Name=Germany", "marker": {"color": "#FFA15A", "size": [45.5799785896], "sizemode": "area", "sizeref": 0.11972850883275, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Germany", "showlegend": true, "type": "scatter", "x": [38982.426304563596], "xaxis": "x", "y": [45.5799785896], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["India"], "ids": ["India"], "legendgroup": "Country Name=India", "marker": {"color": "#19d3f3", "size": [23.032538101999997], "sizemode": "area", "sizeref": 0.11972850883275, "symbol": "circle"}, "mode": "markers", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [4236.744236473301], "xaxis": "x", "y": [23.032538101999997], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Iran, Islamic Rep.<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Iran, Islamic Rep."], "ids": [ ...

# %%
fig.write_html("bubble14.html")

# %% [markdown]
# In this graph we can observed that New Zealand have a high women workforce than many countries. Nevertheless, United States and China are the countries with higher women workforce. We know that China increase in female workforce could be due to their one child policy and perhaps more favorable work evironments than other Asian countries in this list. Nevertheless we observed that Yemen, India and Iran are among the lowest in women workforce and the ones with lower GDP. With this graph it appears that with exception of Saudi Arabia, more women in the workforce correlates with more GDP. To test this hypothesis I run the same variables including all countries with data available.

# %% [markdown]
# ## 7. Bubble graph to asseess the relation between GDP and female in the workforce including all countries

# %%
df1 =pd.read_csv("https://github.com/Shayros/world_development_explorer/raw/main/Project/wdi_dataallcountries.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0  Year  NY.GDP.PCAP.PP.CD  ...      Region Income Group Lending Type
# 0           0  2010        1710.575645  ...  South Asia   Low income          IDA
# 1           1  2011        1699.487997  ...  South Asia   Low income          IDA
# 2           2  2012        1914.774351  ...  South Asia   Low income          IDA
# 3           3  2013        2015.514962  ...  South Asia   Low income          IDA
# 4           4  2014        2069.424642  ...  South Asia   Low income          IDA
#
# [5 rows x 9 columns]

# %%
df1.drop(columns=["Unnamed: 0"], inplace=True) # You can observed above that there is a column title unnamed
df1.sample()
# Out:
#       Year  NY.GDP.PCAP.PP.CD  ...         Income Group Lending Type
# 1470  2015       13551.723492  ...  Upper middle income        Blend
#
# [1 rows x 8 columns]

# %%
px.scatter(df1, x="NY.GDP.PCAP.PP.CD", y="SL.TLF.TOTL.FE.ZS", animation_frame="Year", animation_group="Country Name",
           size="SL.TLF.TOTL.FE.ZS", color="Country Name", hover_name="Country Name", height=600, width=800, labels={
                     "SL.TLF.TOTL.FE.ZS": "Labor force, female (% of total labor force)",
                      "NY.GDP.PCAP.PP.CD": "GDP per capita, PPP (current international $)", # change title to be same as it in the site
             }, )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e2cae46e-b34a-4182-93ae-ca199143ee78" class="plotly-graph-div" style="height:600px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2cae46e-b34a-4182-93ae-ca199143ee78")) {
#                     Plotly.newPlot(
#                         'e2cae46e-b34a-4182-93ae-ca199143ee78',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Afghanistan<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Afghanistan"], "ids": ["Afghanistan"], "legendgroup": "Country Name=Afghanistan", "marker": {"color": "#636efa", "size": [15.479169152999999], "sizemode": "area", "sizeref": 0.1400146481165, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Afghanistan", "showlegend": true, "type": "scatter", "x": [1710.5756453842998], "xaxis": "x", "y": [15.479169152999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Albania<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Albania"], "ids": ["Albania"], "legendgroup": "Country Name=Albania", "marker": {"color": "#EF553B", "size": [42.4440719305], "sizemode": "area", "sizeref": 0.1400146481165, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Albania", "showlegend": true, "type": "scatter", "x": [9636.1087046998], "xaxis": "x", "y": [42.4440719305], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Algeria<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Algeria"], "ids": ["Algeria"], "legendgroup": "Country Name=Algeria", "marker": {"color": "#00cc96", "size": [16.8828113903], "sizemode": "area", "sizeref": 0.1400146481165, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Algeria", "showlegend": true, "type": "scatter", "x": [13095.4468249877], "xaxis": "x", "y": [16.8828113903], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Angola<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Angola"], "ids": ["Angola"], "legendgroup": "Country Name=Angola", "marker": {"color": "#ab63fa", "size": [49.8501004857], "sizemode": "area", "sizeref": 0.1400146481165, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Angola", "showlegend": true, "type": "scatter", "x": [6587.9872210177], "xaxis": "x", "y": [49.8501004857], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Argentina<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Argentina"], "ids": ["Argentina"], "legendgroup": "Country Name=Argentina", "marker": {"color": "#FFA15A", "size": [41.3842910758], "sizemode": "area", "sizeref": 0.1400146481165, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Argentina", "showlegend": true, "type": "scatter", "x": [18061.9343588337], "xaxis": "x", "y": [41.3842910758], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Armenia<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Armenia"], "ids": ["Armenia"], "legendgroup": "Country Name=Armenia", "marker": {"color": "#19d3f3", "size": [45.702670644499996], "sizemode": "area", "sizeref": 0.1400146481165, "symbol": "circle"}, "mode": "markers", "name": "Country Name=Armenia", "showlegend": true, "type": "scatter", "x": [7506.3088645732], "xaxis": "x", "y": [45.702670644499996], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>Year=2010<br>GDP per capita, PPP (current international $)=%{x}<br>Labor force, female (% of total labor force)=%{marker.size}", "hovertext": ["Australia"], "ids": ["Australia"], ...

# %%
fig.write_html("bubbleall.html")

# %% [markdown]
# In this graph we can observed that there around 4 clusters. Ones that have medium to high GDP with low female workforce (mainly oil industries), low female worforce and low GDP, high female worforce but low GDP  and high GDP and high female workforce. We can take for example Iceland where a reduction of female workforce is observed along a reduction in GDP. Nevertheless, the countries with high female and low GDP, there GDP is often than low that although they might see an increase they have less income than other countries. And for those in the top 20 high GDP countries those often in the top are those with higher female in the workforce.

# %% [markdown]
# Lokking back to the fourteen selected countries if we utilize a line graph we can observed how the GDP have been growing over the years in these countries. This will allow us to isolate what might be happening during that year that lead to jumps or drops in GDP.

# %% [markdown]
# ## 8. Line graph to assess changes in GDP per capita during 2010-2019

# %%
fig = px.line(df, x="Year", y="NY.GDP.PCAP.PP.CD", color='Country Name',title="GDP per capita for selected countries during 2010-1019", labels={
                     "NY.GDP.PCAP.PP.CD": "GDP per capita, PPP (current international $)" # change title to be same as it in the site
             },
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3594f631-7e9d-4298-9884-5f9721851afc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3594f631-7e9d-4298-9884-5f9721851afc")) {
#                     Plotly.newPlot(
#                         '3594f631-7e9d-4298-9884-5f9721851afc',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Algeria<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Algeria", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Algeria", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [13095.4468249877, 13500.0416554875, 13303.3317888752, 13056.8036185828, 13003.267118909, 12015.631395101498, 11624.338988843601, 11737.4093527549, 11925.7985636431, 12019.9283559331], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Canada<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Canada", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=Canada", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [40019.926250234705, 41569.449617197, 42290.965410274504, 44298.5787342765, 45753.75055479941, 44670.080538583796, 46472.3402486315, 48490.379498748094, 50939.392593709, 51668.914545682695], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=China<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=China", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [9253.7651876772, 10299.870694002, 11197.5969363537, 11923.7526189386, 12549.7718312938, 12978.768910571102, 13572.6199886903, 14344.4212394407, 15614.3052820791, 16804.425782267], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Egypt, Arab Rep.<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Egypt, Arab Rep.", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Egypt, Arab Rep.", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [9522.5101985566, 9686.0463784655, 11092.7432596071, 11221.3819091064, 10895.9448542272, 11512.4023933352, 11192.372891628, 11014.486136551299, 11643.220497529399, 12283.807365639299], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Germany<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Germany", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=Germany", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [38982.426304563596, 42541.531088409596, 43359.6148271723, 44993.8927459315, 47011.551093513095, 47609.7810045816, 50579.6839299266, 53121.9876792716, 56689.095733198796, 57530.303034463795], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=India<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=India", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [4236.744236473301, 4493.6678035249, 4861.1463707748, 5057.217580850301, 5233.8685428186, 5464.8591405153, 5839.898589050601, 6185.9938925854, 6655.0698600041005, 6996.5569265023], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=Iran, Islamic Rep.<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "legendgroup": "Country Name=Iran, Islamic Rep.", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "Country Name=Iran, Islamic Rep.", "showlegend": true, "type": "scatter ...

# %%
fig.write_html("line.html")

# %% [markdown]
# When we look back to Saudi Arabia we ca observed that their GDP have decrease. Not necesarily in this case due to less women in the workplace but probably due to the oil industry taking some hit. Nevertheless, if we look at New Zealand their GDP have slightly increase with a slightly increase in women in the workplace.
#
# I did a search to determine what happened during this time that their was an increase in the economy with an increase in women in the workplace (4). I found that during this time there was plan that was put into place to help women get into jobs like construction and other reforms were added to help women enter the workforce and guarantee a better work environment(4). If the US and other countries follow the lead of New Zealand we can even see boost in the economy. This is not only about more people working is equal to more profits but it is also more ideas, which equals more innnovation.
#
# The Growing Economies Through Gender Parity established a projection of what could happend if countries adopt gender parity in the workforce and how that will be observed in terms of GDP increase.

# %% [markdown]
# ![](https://github.com/Shayros/world_development_explorer/raw/main/images/pos.increase.png)
# *Image from: https://www.cfr.org/womens-participation-in-global-economy/*
#
# Althought US have 75% of gender parity there still much to be done and we should adopt policies similar to the ones of New Zealand and Canada or even go higher to potentially boost the economy (5). If the US adopt New Zealand strategies there could be an increase of even 12% which is 2.7 trillion gain and around $8,000 per person (5).
#
# Therefore, let's support women in the workplace and create an equal environment for everyone. Creating equality in the workplace will benefit everyone of us.
#
# ![](https://github.com/Shayros/world_development_explorer/raw/main/images/women-in-tech-pillar-page-online-communities-for-women.png)
# *Image from: builtin.com*
#
#
#
#
# ### References:
#
# 1.Yellen, Janet L. (May 2020). *The history of women’s work and wages and how it has created success for us all*.  https://www.brookings.edu/essay/the-history-of-womens-work-and-wages-and-how-it-has-created-success-for-us-all/
#
# 2.Pictute a Scientist: https://www.pictureascientist.com/
#
# 3.El-Swais, Maha (March 09, 2016).World Bank Blogs: Arab Voices. *Despite high education levels, Arab women still don’t have jobs*. https://blogs.worldbank.org/arabvoices/despite-high-education-levels-arab-women-still-don-t-have-jobs
#
# 4.*Getting it done: Utilising women’s skills in the workforce*. https://policygroupontradeswomen.org/wp-content/uploads/2020/08/Getting-it-done-Utilising-women%E2%80%99s-skills-in-the-workforce-Lessons-from-the-Canterbury-New-Zealand-rebuild-2015.pdf
#
# 5.*Growing Economies Through Gender Parity*. https://www.cfr.org/womens-participation-in-global-economy/
